# %% [markdown]
# ======================================================================
#        Adquisición Multicanal de Datos en 4 Canales para Red Pitaya
# ======================================================================
#
# Desarrollado por Ing. Mattenet Mariana
# Departamento de Telecomunicaciones
# Instituto Balseiro - Comisión Nacional de Energía Atómica -
# Año: 2025
#
# Descripción:
# ------------
# Este script permite la adquisición de datos en una Red Pitaya, capturando
# señales en múltiples canales de manera simultánea con un trigger basado en
# un umbral configurable. Los datos se almacenan en archivos HDF5 para una
# manipulación eficiente.
#
# Funcionalidades principales:
# ----------------------------
# - Selección de canales de adquisición (1 a 4).
# - Configuración de parámetros de adquisición:
#   * Nivel de trigger (V)
#   * Número de muestras por evento
#   * Delay de muestras
# - Cálculo automático del número máximo de eventos según el espacio disponible en SD.
# - Creación y manejo de archivos HDF5 para almacenar los datos de forma estructurada.
# - División de archivos cuando alcanzan un umbral de tamaño.
# - Configuración de la hora de adquisición (automática o manual).
#
# Flujo del programa:
# -------------------
# 1. Configuración del entorno y selección de la hora de adquisición.
# 2. Inicialización de la FPGA y configuración del sistema de adquisición.
# 3. Selección de canales y parámetros de adquisición.
# 4. Cálculo del número de eventos posibles según el espacio disponible.
# 5. Inicio de la adquisición:
#     - Espera de eventos con trigger.
#     - Captura de datos y almacenamiento en archivos HDF5.
#     - Creación de nuevos archivos si se supera el tamaño umbral.
# 6. Finalización del proceso y liberación de la FPGA.
#
# Formato de los archivos HDF5 generados:
# ----------------------------------------
# - Nombre del archivo: `Data_YYMMDD_HHMM_XXXX.h5`
#   (YYMMDD: año, mes, día; HHMM hora, minutos; XXXX: índice secuencial)
# - Atributos generales:
#   * Hora de inicio de adquisición
#   * Tasa de muestreo
#   * Nivel de trigger
#   * Número de muestras por evento y delay
#   * Canales utilizados
#   * Cantidad total de eventos
# - Estructura por evento:
#   /event_000001/
#     ├── channel_1 (array de muestras)
#     ├── channel_2 (array de muestras)
#     ├── channel_3 (array de muestras)
#     ├── channel_4 (array de muestras)
#     ├── timestamp (marca de tiempo del trigger)
#
# Advertencias:
# -------------
# - Asegúrese de que la tarjeta SD tenga suficiente espacio libre (al menos 200 MB recomendados).
# - Verifique que la Red Pitaya esté correctamente conectada y configurada antes de iniciar la adquisición.
# - Si no se detectan triggers, el proceso puede quedar esperando eventos.
# - Tenga en cuenta que el rango de tensión de las entradas de la Red Pitaya depende de la configuración del
# jumper en la placa (HV: ±20 V, LV: ±1 V). Se recomienda verificar que las señales a adquirir estén dentro
# del rango adecuado antes de comenzar la adquisición.
#
# Para más información, consulte la documentación oficial:
# https://redpitaya.readthedocs.io/en/latest/intro.html
#
# Uso:
# ----
# Simplemente ejecute el script en Python. Se le pedirá que ingrese los parámetros necesarios.
#
# Para más información, consulte la documentación oficial de Red Pitaya:
# https://redpitaya.readthedocs.io/en/latest/intro.html
#
# Descripción:
# Este programa realiza la adquisición de datos en una Red Pitaya,
# capturando señales en hasta 4 canales de manera simultánea con un trigger
# basado en un umbral en el canal 2 (opcional). Utiliza un buffer circular de
# tamaño 16,384 muestras y permite configurar parámetros como número de muestras
# por evento, retraso de muestras y cantidad de eventos a capturar.
#
# Antes de iniciar la adquisición, se deben configurar los parametros de adquisicion
# deseados y seleccionar si la captura será continua o acotada al espacio libre en
# la SD de la RedPitaya. Si se elige esta última opción el programa verifica el
# espacio libre en la SD y se calcula el número máximo de eventos permitidos, asegurando
# al menos 200 MB libres.
#
# Los datos adquiridos se almacenan en formato HDF5, permitiendo optimización y
# manipulación eficiente de grandes volúmenes de datos. Si se desea trabajar con
# adquisición de grandes volumenes de datos se puede ejecutar el programa monitor_hdf5
# que transmite los datos capturados a traves de la red y los borra de la memoria de la
# RedPitaya para liberar espacio.
#
# Nota: El rango de tensión de las entradas de la Red Pitaya depende de la
# configuración del jumper en la placa (HV: ±20 V, LV: ±1 V). Se recomienda
# verificar que las señales medidas estén dentro del rango adecuado antes
# de la adquisición. Para más información, consulte la documentación oficial:
# https://redpitaya.readthedocs.io/en/latest/intro.html
#
# ==============================================================
#
# # Descripción:
# Este programa realiza la adquisición de datos en una Red Pitaya, capturando señales en hasta 4 canales de manera simultánea con un trigger basado en un umbral en el canal 2 (opcional). Utiliza un buffer circular de tamaño 16384 muestras y permite configurar parámetros como número de muestras por evento, retraso de muestras y cantidad de eventos a capturar.
#
# Antes de iniciar la adquisición, se verifica el espacio libre en la SD
# y se calcula el número máximo de eventos permitidos, asegurando al menos
# 200 MB libres. Los datos adquiridos se almacenan en formato HDF5,
# permitiendo optimización y manipulación eficiente de grandes volúmenes
# de datos. Si se desea trabajar con adquisición de grandes volúmenes de datos
# , se puede ejecutar el programa monitor_hdf5 que transmite los datos capturados a través de la red y los borra de la memoria de la RedPitaya para liberar espacio.
#
# La adquisición se detiene si luego de 2 horas, el programa no detecta señales que disparen la adquisición configurada por el usuario.
#
# Nota: El rango de tensión de las entradas de la Red Pitaya depende de la
# configuración del jumper en la placa (HV: ±20 V, LV: ±1 V). Se recomienda
# verificar que las señales medidas estén dentro del rango adecuado antes
# de la adquisición. Para más información, consulte la documentación oficial:
# https://redpitaya.readthedocs.io/en/latest/intro.html
# #==============================================================

# %%
import os
import time
import numpy as np
import h5py
from datetime import datetime
from zoneinfo import ZoneInfo
import rp
from rp_overlay import overlay
import pathlib
from matplotlib import pyplot as plt

# -----------------------------FUNCIONES-----------------------------------

def get_free_space_mb(path="/"):
    """Obtiene el espacio libre en la SD en MB."""
    statvfs = os.statvfs(path)
    free_space = statvfs.f_bavail * statvfs.f_frsize
    return free_space / (1024 * 1024)


def interpolate_params(channels):
    """Interpola los parámetros F y P (en KB) en función de la cantidad de canales (para 32 muestras)."""
    if channels <= 1:
        return 2.68, 1.59
    elif channels >= 4:
        return 5.10, 2.30
    else:
        F = 2.68 + (5.10 - 2.68) * (channels - 1) / (4 - 1)
        P = 1.59 + (2.30 - 1.59) * (channels - 1) / (4 - 1)
        return F, P


def estimate_file_size(channels, samples, events):
    """Estima el tamaño del archivo (en KB) en función de los eventos."""
    data_payload = (channels * samples * 4) / 1024.0
    F, P = interpolate_params(channels)
    total_size = F + (events - 1) * (data_payload + P)
    return total_size


def get_max_events_or_time(samples, channels):
    """Permite configurar límite por cantidad de eventos o duración."""
    print("\n\n=================================================================")
    print("\033[1m   Configuración de almacenamiento de datos\033[0m")
    print("=================================================================\n")

    free_space = get_free_space_mb()
    available_space_mb = free_space - 200  # Deja 200 MB libres
    if available_space_mb <= 0:
        print("⚠️ No hay suficiente espacio libre en la SD. Libera espacio antes de continuar.")
        exit()

    available_space_kb = available_space_mb * 1024
    per_event_size = estimate_file_size(channels, samples, 1)
    max_events = int(available_space_kb // per_event_size)

    print(f"🔷 Espacio disponible (dejando 200 MB libres): {available_space_mb:.2f} MB")
    print(f"🔷 Máximo de eventos que se pueden guardar: {max_events}")

    print("\n🔴 ¿Deseas limitar la grabación por cantidad de eventos o por duración?")
    print("    E - número de eventos (default)")
    print("    T - duración en minutos")
    option = input(" ").strip().lower()

    if option == 't':
        while True:
            try:
                minutes = float(input("⏳ ¿Cuántos minutos deseas grabar? (Ej: 1.5): ").strip())
                if minutes <= 0:
                    raise ValueError("El tiempo debe ser mayor que cero.")
                print(f"✅ Se grabará durante {minutes} minutos o hasta llenar la SD.")
                return {'mode': 'time', 'duration_minutes': minutes, 'max_events': max_events}
            except ValueError as e:
                print(f"⚠️ Entrada inválida: {e}")
    else:
        default_events = 10
        try:
            user_input = input(f"🔴 ¿Cuántos eventos deseas guardar? (Máximo {max_events}, Enter usa {default_events}): ").strip()
            num_events = int(user_input) if user_input else default_events
        except ValueError:
            print("⚠️ Entrada inválida. Se guardarán 10 eventos por defecto.")
            num_events = default_events

        num_events = min(num_events, max_events)
        est_size = estimate_file_size(channels, samples, num_events)
        print(f"🔷 Tamaño estimado para {num_events} eventos: {est_size:.2f} KB")
        return {'mode': 'events', 'num_events': num_events}


def select_channels(available_channels=[1, 2, 3, 4]):
    """Permite seleccionar qué canales capturar."""
    user_input = input("🔴 Ingresa los canales a capturar (Ej: 1,2,3,4 o 1 2 3 4). 'Enter' usa todos: ")
    if user_input.strip() == "":
        return available_channels
    try:
        channels = [int(ch) for ch in user_input.replace(",", " ").split() if ch.strip().isdigit()]
        channels = [ch for ch in channels if ch in available_channels]
        return channels if channels else available_channels
    except:
        print("⚠️ Error en la entrada, usando todos los canales.")
        return available_channels


def select_trigger_source():
    """Selecciona canal y flanco del trigger."""
    edge_input = input("🔴 Tipo de flanco (P = positivo, N = negativo) [Default: P]: ").strip().upper()
    edge = edge_input if edge_input in ["P", "N"] else "P"

    while True:
        channel_input = input("🔴 Canal de trigger (1–4) [Default: 1]: ").strip()
        try:
            ch = int(channel_input) if channel_input else 1
            if ch in [1, 2, 3, 4]:
                break
            else:
                print("⚠️ Canal inválido. Debe ser 1 a 4.")
        except ValueError:
            print("⚠️ Entrada inválida, usando canal 1.")

    channel_letter = ["A", "B", "C", "D"][ch - 1]
    suffix = "PE" if edge == "P" else "NE"
    const_name = f"RP_TRIG_SRC_CH{channel_letter}_{suffix}"
    trigger_source = getattr(rp, const_name)
    trigger_channel = getattr(rp, f"RP_CH_{ch}")

    print(f"   --> Trigger: Canal {ch}, flanco {'positivo' if edge == 'P' else 'negativo'} ({const_name})")

    return trigger_source, trigger_channel, ch, suffix


def get_user_input(prompt, default_value, cast_type=float):
    """Obtiene un valor del usuario, con valor por defecto."""
    user_input = input(f"{prompt} ('Enter' usa {default_value}): ").strip()
    try:
        return cast_type(user_input) if user_input else default_value
    except ValueError:
        print("⚠️ Entrada inválida, usando valor por defecto.")
        return default_value


def create_custom_time():
    """Permite crear una fecha/hora personalizada."""
    while True:
        try:
            day = int(input("📅 Día (1–31): "))
            month = int(input("📅 Mes (1–12): "))
            year = int(input("📅 Año (ej. 2025): "))
            hour = int(input("🕒 Hora (0–23): "))
            minute = int(input("🕒 Minuto (0–59): "))
            return datetime(year, month, day, hour, minute, 0)
        except ValueError as e:
            print(f"❌ Error: {e}. Intenta de nuevo.")


def generar_nombre_archivo(file_index):
    """Genera nombre de archivo secuencial."""
    return f"Data_{day_time_of_first_pulse}_{file_index:04d}.h5"


# -----------------------------INICIO DEL PROGRAMA-----------------------------------

print("=================================================================")
print("\033[1m          Adquisición de datos para Red Pitaya\033[0m")
print("=================================================================\n")

try:
    os.chdir(os.path.dirname(os.path.abspath(__file__)))
except NameError:
    pass

set_time = datetime.now(ZoneInfo("America/Argentina/Buenos_Aires"))
print(f"\033[1m     Hora del sistema: {set_time}\033[0m\n")
time_option = input(f"🔴 ¿Usar hora del sistema o personalizada? (S = sistema, C = custom): ").strip().lower()
if time_option == 'c':
    set_time = create_custom_time()
    print(f"ℹ️ Hora utilizada: {set_time}\n")

sys_time_ns = int(datetime.now().timestamp() * 1e9)
set_time_ns = int(set_time.timestamp() * 1e9)

print("\n🟢 INICIANDO FPGA...\n")
fpga = overlay()
rp.rp_Init()

dec = rp.RP_DEC_1
trig_dly = 0
N = 16384

print("\n\n=================================================================")
print("\033[1m   Configuración de los parámetros de adquisición\033[0m")
print("=================================================================\n")

acq_trig_sour, trig_channel, channel, flanco = select_trigger_source()
trig_lvl = get_user_input("🔴 Nivel de trigger [V]", 0.01)

rp.rp_AcqSetTriggerSrc(acq_trig_sour)
rp.rp_AcqSetTriggerLevel(trig_channel, trig_lvl)

samples = get_user_input("\n🔴 Número de muestras por evento", 32, int)
samples_delay = get_user_input("🔴 Delay de muestras", 8, int)

available_channels = [1, 2, 3, 4]
channels_to_acquire = select_channels(available_channels)
num_channels = len(channels_to_acquire)
config = get_max_events_or_time(samples, num_channels)
print(config)

fs = 125e6 / dec
dt = 1 / fs
time_axis = np.linspace(0, (samples - 1) * dt, samples)

print("\n\n=================================================================")
print("\033[1m PARÁMETROS DE ADQUISICIÓN SELECCIONADOS\033[0m")
print("=================================================================\n")
print(f"🔷 Frecuencia de muestreo = {fs/1e6:.2f} MHz")
print(f"🔷 Canal de trigger: {channel}")
print(f"🔷 Flanco = {flanco}")
print(f"🔷 Nivel de trigger = {trig_lvl} V")
print(f"🔷 Muestras por evento = {samples}")
print(f"🔷 Delay de muestras = {samples_delay}")
print(f"🔷 Canales seleccionados = {channels_to_acquire}")
print(f"🔷 Hora del sistema: {set_time}")
if config['mode'] == 'events':
    print(f"🔷 Eventos a adquirir: {config['num_events']}.\n")
else:
    print(f"🔷 Adquisición durante {config['duration_minutes']} minutos.\n")

day_time_of_first_pulse = set_time.strftime('%Y%m%d_%H%M')

# --- Crear carpeta de salida ---
BASE_DIR = pathlib.Path("/home/jupyter/RedPitaya/DATOS").resolve()
trig_mV = int(trig_lvl * 1000)
trig_str = f"{trig_mV:+03d}"[:3]
folder_name = f"Data_{day_time_of_first_pulse}_TCH{channel}_TL{trig_str}"
output_dir = BASE_DIR / folder_name
output_dir.mkdir(exist_ok=True, parents=True)
os.chdir(output_dir)
print(f"📂 Ruta a carpeta de DATOS: {output_dir}\n")

# CONFIGURACIÓN DE PARTICIONAMIENTO
file_threshold_bytes = 10 * 1024 * 1024  # 10 MB
current_file_size = 0
file_index = 1
h5file = None

trigger_times = []
event = 0
start_time = time.time()
max_wait_between_triggers = 60
max_total_duration = config['duration_minutes'] * 60 if config['mode'] == 'time' else float('inf')
max_events = config['num_events'] if config['mode'] == 'events' else config['max_events']

print("\033[1m🟢 INICIANDO ADQUISICIÓN...\033[0m\n")

trigger_times = []
first_trigger_ns = None
print("\n=========================================================")
print(f"   Ciclo            Estado            Tiempo relativo  ")
print("=========================================================")
while True:
    elapsed_total = time.time() - start_time
    if config['mode'] == 'events' and event >= max_events:
        break
    if config['mode'] == 'time' and (elapsed_total >= max_total_duration or event >= max_events):
        break

    print(f" {event + 1}/{'∞' if config['mode'] == 'time' else max_events}\t        Esperando   trigger  ")



    rp.rp_AcqStart()
    rp.rp_AcqSetTriggerSrc(acq_trig_sour)
    wait_start = time.time()
    triggered = False

    while True:
        if rp.rp_AcqGetTriggerState()[1] == rp.RP_TRIG_STATE_TRIGGERED:
            triggered = True
            break
        if (time.time() - wait_start) >= max_wait_between_triggers:
            print("No se detectaron triggers durante el tiempo máximo de espera. Finalizando...")
            triggered = False
            break
        if config['mode'] == 'time' and (time.time() - start_time) >= max_total_duration:
            triggered = False
            break
        time.sleep(0.001)
    # print (triggered)
    # print(not(triggered))

    if not triggered:
        rp.rp_AcqStop()
        break

    # # Inicializar el tiempo del trigger relativo a 0 ns para mostrar en pantalla
    # first_trigger_ns = None
    # trigger_times = []
    
    # Tiempo relativo al primer trigger 
    trigger_time_ns = time.time_ns()
    trigger_times.append(trigger_time_ns)
    
    if first_trigger_ns is None:
        first_trigger_ns = trigger_time_ns
        relative_ns = 0
    else:
        relative_ns = trigger_time_ns - first_trigger_ns
    
    # imprimir en ns (o elegir unidad legible si preferís)
    print(f"               → Trigger detectado         {round(relative_ns/1e6)} ms   ")
    print("---------------------------------------------------------")

    if h5file is None:
        current_filename = generar_nombre_archivo(file_index)
        h5file = h5py.File(current_filename, "w")
        # --- metadatos iniciales ---
        h5file.attrs.update({
            'set_time': set_time_ns,
            'sys_time': sys_time_ns,
            'decimation': dec,
            'trigger_level': trig_lvl,
            'trigger_channel': channel,
            'trigger_flank': flanco,
            'trigger_delay': trig_dly,
            'samples_per_event': samples,
            'samples_delay': samples_delay,
            'channels': np.array(channels_to_acquire),
            'sampling_rate': fs,
            'mode': config['mode']
        })
        if config['mode'] == "time":
            h5file.attrs['duration_minutes'] = config['duration_minutes']
        else:
            h5file.attrs['num_events'] = config['num_events']

    time.sleep(samples / (125e6 / dec))

    fbuffers = {ch: rp.fBuffer(N) for ch in channels_to_acquire}
    data = {}
    for ch in channels_to_acquire:
        rp.rp_AcqGetOldestDataV(getattr(rp, f'RP_CH_{ch}'), N, fbuffers[ch])
        data[f'channel_{ch}'] = np.array([
            fbuffers[ch][i + N // 2 - samples_delay] for i in range(samples)
        ], dtype=np.float32)

    # --- Control real de tamaño ---
    if h5file is not None:
        current_file_size = os.path.getsize(h5file.filename)
    event_size_bytes = samples * num_channels * 4

    if h5file is not None and (current_file_size + event_size_bytes >= file_threshold_bytes):
        h5file.close()
        file_index += 1
        current_filename = generar_nombre_archivo(file_index)
        h5file = h5py.File(current_filename, "w")
        h5file.attrs.update({
            'set_time': set_time_ns,
            'sys_time': sys_time_ns,
            'decimation': dec,
            'trigger_level': trig_lvl,
            'trigger_channel': channel,
            'trigger_flank': flanco,
            'trigger_delay': trig_dly,
            'samples_per_event': samples,
            'samples_delay': samples_delay,
            'channels': np.array(channels_to_acquire),
            'sampling_rate': fs,
            'mode': config['mode']
        })
        if config['mode'] == "time":
            h5file.attrs['duration_minutes'] = config['duration_minutes']
        else:
            h5file.attrs['num_events'] = config['num_events']
        print(f"\n📁 Nuevo archivo creado: {current_filename}\n")

    # --- Guardar evento ---
    group = h5file.create_group(f"event_{event + 1:06d}")
    group.attrs['timestamp'] = trigger_time_ns
    for ch in channels_to_acquire:
        group.create_dataset(f"channel_{ch}", data=data[f'channel_{ch}'])

    rp.rp_AcqStop()
    event += 1

# Finalización
if h5file is not None:
    h5file.close()
rp.rp_Release()

print("\n✅ Adquisición finalizada.")

if trigger_times:
    elapsed_time = (trigger_times[-1] - trigger_times[0]) / 1e9
    print(f"\n⏱️ Tiempo entre primer y último trigger: {elapsed_time:.6f} s")
# Out:
# =================================================================
#           Adquisición de datos para Red Pitaya
# =================================================================
#
#      Hora del sistema: 2025-10-29 17:17:35.171660-03:00
# 🔴 ¿Usar hora del sistema o personalizada? (S = sistema, C = custom):  s
# 🟢 INICIANDO FPGA...
#
# Check FPGA [OK].
#
#
# =================================================================
#    Configuración de los parámetros de adquisición
# =================================================================
# 🔴 Tipo de flanco (P = positivo, N = negativo) [Default: P]:  n
# 🔴 Canal de trigger (1–4) [Default: 1]:  4
#    --> Trigger: Canal 4, flanco negativo (RP_TRIG_SRC_CHD_NE)
# 🔴 Nivel de trigger [V] ('Enter' usa 0.01):  0
#
# 🔴 Número de muestras por evento ('Enter' usa 32):
# 🔴 Delay de muestras ('Enter' usa 8):
# 🔴 Ingresa los canales a capturar (Ej: 1,2,3,4 o 1 2 3 4). 'Enter' usa todos:
# =================================================================
#    Configuración de almacenamiento de datos
# =================================================================
#
# 🔷 Espacio disponible (dejando 200 MB libres): 984.44 MB
# 🔷 Máximo de eventos que se pueden guardar: 197659
#
# 🔴 ¿Deseas limitar la grabación por cantidad de eventos o por duración?
#     E - número de eventos (default)
#     T - duración en minutos
#
# 🔴 ¿Cuántos eventos deseas guardar? (Máximo 197659, Enter usa 10):  100000
# 🔷 Tamaño estimado para 100000 eventos: 280002.30 KB
# {'mode': 'events', 'num_events': 100000}
#
#
# =================================================================
#  PARÁMETROS DE ADQUISICIÓN SELECCIONADOS
# =================================================================
#
# 🔷 Frecuencia de muestreo = 125.00 MHz
# 🔷 Canal de trigger: 4
# 🔷 Flanco = NE
# 🔷 Nivel de trigger = 0.0 V
# 🔷 Muestras por evento = 32
# 🔷 Delay de muestras = 8
# 🔷 Canales seleccionados = [1, 2, 3, 4]
# 🔷 Hora del sistema: 2025-10-29 17:17:35.171660-03:00
# 🔷 Eventos a adquirir: 100000.
#
# 📂 Ruta a carpeta de DATOS: /home/jupyter/RedPitaya/DATOS/Data_20251029_1717_TCH4_TL+00
#
# 🟢 INICIANDO ADQUISICIÓN...
#
#
# =========================================================
#    Ciclo            Estado            Tiempo relativo
# =========================================================
#  1/100000	        Esperando   trigger
#                → Trigger detectado         0 ms
# ---------------------------------------------------------
#  2/100000	        Esperando   trigger
#                → Trigger detectado         61 ms
# ---------------------------------------------------------
#  3/100000	        Esperando   trigger
#                → Trigger detectado         100 ms
# ---------------------------------------------------------
#  4/100000	        Esperando   trigger
#                → Trigger detectado         149 ms
# ---------------------------------------------------------
#  5/100000	        Esperando   trigger
#                → Trigger detectado         192 ms
# ---------------------------------------------------------
#  6/100000	        Esperando   trigger
#                → Trigger detectado         228 ms
# ---------------------------------------------------------
#  7/100000	        Esperando   trigger
#                → Trigger detectado         264 ms
# ---------------------------------------------------------
#  8/100000	        Esperando   trigger
#                → Trigger detectado         306 ms
# ---------------------------------------------------------
#  9/100000	        Esperando   trigger
#                → Trigger detectado         341 ms
# ---------------------------------------------------------
#  10/100000	        Esperando   trigger
#                → Trigger detectado         378 ms
# ---------------------------------------------------------
#  11/100000	        Esperando   trigger
#                → Trigger detectado         424 ms
# ---------------------------------------------------------
#  12/100000	        Esperando   trigger
#                → Trigger detectado         463 ms
# ---------------------------------------------------------
#  13/100000	        Esperando   trigger
#                → Trigger detectado         501 ms
# ---------------------------------------------------------
#  14/100000	        Esperando   trigger
#                → Trigger detectado         539 ms
# ---------------------------------------------------------
#  15/100000	        Esperando   trigger
#                → Trigger detectado         576 ms
# ---------------------------------------------------------
#  16/100000	        Esperando   trigger
#                → Trigger detectado         613 ms
# ---------------------------------------------------------
#  17/100000	        Esperando   trigger
#                → Trigger detectado         659 ms
# ---------------------------------------------------------
#  18/100000	        Esperando   trigger
#                → Trigger detectado         699 ms
# ---------------------------------------------------------
#  19/100000	        Esperando   trigger
#                → Trigger detectado         740 ms
# ---------------------------------------------------------
#  20/100000	        Esperando   trigger
#                → Trigger detectado         781 ms
# ---------------------------------------------------------
#  21/100000	        Esperando   trigger
#                → Trigger detectado         817 ms
# ---------------------------------------------------------
#  22/100000	        Esperando   trigger
#                → Trigger detectado         862 ms
# ---------------------------------------------------------
#  23/100000	        Esperando   trigger
#                → Trigger detectado         899 ms
# ---------------------------------------------------------
#  24/100000	        Esperando   trigger
#                → Trigger detectado         938 ms
# ---------------------------------------------------------
#  25/100000	        Esperando   trigger
#                → Trigger detectado         976 ms
# ---------------------------------------------------------
#  26/100000	        Esperando   trigger
#                → Trigger detectado         1014 ms
# ---------------------------------------------------------
#  27/100000	        Esperando   trigger
#                → Trigger detectado         1050 ms
# ---------------------------------------------------------
#  28/100000	        Esperando   trigger
#                → Trigger detectado         1096 ms
# ---------------------------------------------------------
#  29/100000	        Esperando   trigger
#                → Trigger detectado         1138 ms
# ---------------------------------------------------------
#  30/100000	        Esperando   trigger
#                → Trigger detectado         1177 ms
# ---------------------------------------------------------
#  31/100000	        Esperando   trigger
#                → Trigger detectado         1215 ms
# ---------------------------------------------------------
#  32/100000	        Esperando   trigger
#                → Trigger detectado         1252 ms
# ---------------------------------------------------------
#  33/100000	        Esperando   trigger
#                → Trigger detectado         1291 ms
# ---------------------------------------------------------
#  34/100000	        Esperando   trigger
#                → Trigger detectado         1335 ms
# ---------------------------------------------------------
#  35/100000	        Esperando   trigger
#                → Trigger detectado         1376 ms
# ---------------------------------------------------------
#  36/100000	        Esperando   trigger
#                → Trigger detectado         1412 ms
# ---------------------------------------------------------
#  37/100000	        Esperando   trigger
#                → Trigger detectado         1449 ms
# ---------------------------------------------------------
#  38/100000	        Esperando   trigger
#                → Trigger detectado         1490 ms
# ---------------------------------------------------------
#  39/100000	        Esperando   trigger
#                → Trigger detectado         1526 ms
# ---------------------------------------------------------
#  40/100000	        Esperando   trigger
#                → Trigger detectado         1571 ms
# ---------------------------------------------------------
#  41/100000	        Esperando   trigger
#                → Trigger detectado         1607 ms
# ---------------------------------------------------------
#  42/100000	        Esperando   trigger
#                → Trigger detectado         1643 ms
# ---------------------------------------------------------
#  43/100000	        Esperando   trigger
#                → Trigger detectado         1678 ms
# ---------------------------------------------------------
#  44/100000	        Esperando   trigger
#                → Trigger detectado         1715 ms
# ---------------------------------------------------------
#  45/100000	        Esperando   trigger
#                → Trigger detectado         1751 ms
# ---------------------------------------------------------
#  46/100000	        Esperando   trigger
#                → Trigger detectado         1796 ms
# ---------------------------------------------------------
#  47/100000	        Esperando   trigger
#                → Trigger detectado         1835 ms
# ---------------------------------------------------------
#  48/100000	        Esperando   trigger
#                → Trigger detectado         1886 ms
# ---------------------------------------------------------
#  49/100000	        Esperando   trigger
#                → Trigger detectado         1927 ms
# ---------------------------------------------------------
#  50/100000	        Esperando   trigger
#                → Trigger detectado         1965 ms
# ---------------------------------------------------------
#  51/100000	        Esperando   trigger
#                → Trigger detectado         2011 ms
# ---------------------------------------------------------
#  52/100000	        Esperando   trigger
#                → Trigger detectado         2047 ms
# ---------------------------------------------------------
#  53/100000	        Esperando   trigger
#                → Trigger detectado         2084 ms
# ---------------------------------------------------------
#  54/100000	        Esperando   trigger
#                → Trigger detectado         2125 ms
# ---------------------------------------------------------
#  55/100000	        Esperando   trigger
#                → Trigger detectado         2167 ms
# ---------------------------------------------------------
#  56/100000	        Esperando   trigger
#                → Trigger detectado         2213 ms
# ---------------------------------------------------------
#  57/100000	        Esperando   trigger
#                → Trigger detectado         2252 ms
# ---------------------------------------------------------
#  58/100000	        Esperando   trigger
#                → Trigger detectado         2292 ms
# ---------------------------------------------------------
#  59/100000	        Esperando   trigger
#                → Trigger detectado         2331 ms
# ---------------------------------------------------------
#  60/100000	        Esperando   trigger
#                → Trigger detectado         2374 ms
# ---------------------------------------------------------
#  61/100000	        Esperando   trigger
#                → Trigger detectado         2411 ms
# ---------------------------------------------------------
#  62/100000	        Esperando   trigger
#                → Trigger detectado         2465 ms
# ---------------------------------------------------------
#  63/100000	        Esperando   trigger
#                → Trigger detectado         2510 ms
# ---------------------------------------------------------
#  64/100000	        Esperando   trigger
#                → Trigger detectado         2550 ms
# ---------------------------------------------------------
#  65/100000	        Esperando   trigger
#                → Trigger detectado         2586 ms
# ---------------------------------------------------------
#  66/100000	        Esperando   trigger
#                → Trigger detectado         2634 ms
# ---------------------------------------------------------
#  67/100000	        Esperando   trigger
#                → Trigger detectado         2681 ms
# ---------------------------------------------------------
#  68/100000	        Esperando   trigger
#                → Trigger detectado         2730 ms
# ---------------------------------------------------------
#  69/100000	        Esperando   trigger
#                → Trigger detectado         2766 ms
# ---------------------------------------------------------
#  70/100000	        Esperando   trigger
#                → Trigger detectado         2802 ms
# ---------------------------------------------------------
#  71/100000	        Esperando   trigger
#                → Trigger detectado         2839 ms
# ---------------------------------------------------------
#  72/100000	        Esperando   trigger
#                → Trigger detectado         2875 ms
# ---------------------------------------------------------
#  73/100000	        Esperando   trigger
#                → Trigger detectado         2923 ms
# ---------------------------------------------------------
#  74/100000	        Esperando   trigger
#                → Trigger detectado         2969 ms
# ---------------------------------------------------------
#  75/100000	        Esperando   trigger
#                → Trigger detectado         3026 ms
# ---------------------------------------------------------
#  76/100000	        Esperando   trigger
#                → Trigger detectado         3062 ms
# ---------------------------------------------------------
#  77/100000	        Esperando   trigger
#                → Trigger detectado         3113 ms
# ---------------------------------------------------------
#  78/100000	        Esperando   trigger
#                → Trigger detectado         3160 ms
# ---------------------------------------------------------
#  79/100000	        Esperando   trigger
#                → Trigger detectado         3199 ms
# ---------------------------------------------------------
#  80/100000	        Esperando   trigger
#                → Trigger detectado         3234 ms
# ---------------------------------------------------------
#  81/100000	        Esperando   trigger
#                → Trigger detectado         3277 ms
# ---------------------------------------------------------
#  82/100000	        Esperando   trigger
#                → Trigger detectado         3323 ms
# ---------------------------------------------------------
#  83/100000	        Esperando   trigger
#                → Trigger detectado         3378 ms
# ---------------------------------------------------------
#  84/100000	        Esperando   trigger
#                → Trigger detectado         3426 ms
# ---------------------------------------------------------
#  85/100000	        Esperando   trigger
#                → Trigger detectado         3463 ms
# ---------------------------------------------------------
#  86/100000	        Esperando   trigger
#                → Trigger detectado         3499 ms
# ---------------------------------------------------------
#  87/100000	        Esperando   trigger
#                → Trigger detectado         3534 ms
# ---------------------------------------------------------
#  88/100000	        Esperando   trigger
#                → Trigger detectado         3585 ms
# ---------------------------------------------------------
#  89/100000	        Esperando   trigger
#                → Trigger detectado         3624 ms
# ---------------------------------------------------------
#  90/100000	        Esperando   trigger
#                → Trigger detectado         3663 ms
# ---------------------------------------------------------
#  91/100000	        Esperando   trigger
#                → Trigger detectado         3703 ms
# ---------------------------------------------------------
#  92/100000	        Esperando   trigger
#                → Trigger detectado         3757 ms
# ---------------------------------------------------------
#  93/100000	        Esperando   trigger
#                → Trigger detectado         3801 ms
# ---------------------------------------------------------
#  94/100000	        Esperando   trigger
#                → Trigger detectado         3842 ms
# ---------------------------------------------------------
#  95/100000	        Esperando   trigger
#                → Trigger detectado         3881 ms
# ---------------------------------------------------------
#  96/100000	        Esperando   trigger
#                → Trigger detectado         3920 ms
# ---------------------------------------------------------
#  97/100000	        Esperando   trigger
#                → Trigger detectado         3956 ms
# ---------------------------------------------------------
#  98/100000	        Esperando   trigger
#                → Trigger detectado         4009 ms
# ---------------------------------------------------------
#  99/100000	        Esperando   trigger
#                → Trigger detectado         4053 ms
# ---------------------------------------------------------
#  100/100000	        Esperando   trigger
#                → Trigger detectado         4092 ms
# ---------------------------------------------------------
#  101/100000	        Esperando   trigger
#                → Trigger detectado         4137 ms
# ---------------------------------------------------------
#  102/100000	        Esperando   trigger
#                → Trigger detectado         4174 ms
# ---------------------------------------------------------
#  103/100000	        Esperando   trigger
#                → Trigger detectado         4215 ms
# ---------------------------------------------------------
#  104/100000	        Esperando   trigger
#                → Trigger detectado         4253 ms
# ---------------------------------------------------------
#  105/100000	        Esperando   trigger
#                → Trigger detectado         4290 ms
# ---------------------------------------------------------
#  106/100000	        Esperando   trigger
#                → Trigger detectado         4328 ms
# ---------------------------------------------------------
#  107/100000	        Esperando   trigger
#                → Trigger detectado         4365 ms
# ---------------------------------------------------------
#  108/100000	        Esperando   trigger
#                → Trigger detectado         4407 ms
# ---------------------------------------------------------
#  109/100000	        Esperando   trigger
#                → Trigger detectado         4458 ms
# ---------------------------------------------------------
#  110/100000	        Esperando   trigger
#                → Trigger detectado         4496 ms
# ---------------------------------------------------------
#  111/100000	        Esperando   trigger
#                → Trigger detectado         4531 ms
# ---------------------------------------------------------
#  112/100000	        Esperando   trigger
#                → Trigger detectado         4569 ms
# ---------------------------------------------------------
#  113/100000	        Esperando   trigger
#                → Trigger detectado         4607 ms
# ---------------------------------------------------------
#  114/100000	        Esperando   trigger
#                → Trigger detectado         4650 ms
# ---------------------------------------------------------
#  115/100000	        Esperando   trigger
#                → Trigger detectado         4703 ms
# ---------------------------------------------------------
#  116/100000	        Esperando   trigger
#                → Trigger detectado         4739 ms
# ---------------------------------------------------------
#  117/100000	        Esperando   trigger
#                → Trigger detectado         4775 ms
# ---------------------------------------------------------
#  118/100000	        Esperando   trigger
#                → Trigger detectado         4811 ms
# ---------------------------------------------------------
#  119/100000	        Esperando   trigger
#                → Trigger detectado         4850 ms
# ---------------------------------------------------------
#  120/100000	        Esperando   trigger
#                → Trigger detectado         4897 ms
# ---------------------------------------------------------
#  121/100000	        Esperando   trigger
#                → Trigger detectado         4936 ms
# ---------------------------------------------------------
#  122/100000	        Esperando   trigger
#                → Trigger detectado         4974 ms
# ---------------------------------------------------------
#  123/100000	        Esperando   trigger
#                → Trigger detectado         5012 ms
# ---------------------------------------------------------
#  124/100000	        Esperando   trigger
#                → Trigger detectado         5050 ms
# ---------------------------------------------------------
#  125/100000	        Esperando   trigger
#                → Trigger detectado         5087 ms
# ---------------------------------------------------------
#  126/100000	        Esperando   trigger
#                → Trigger detectado         5139 ms
# ---------------------------------------------------------
#  127/100000	        Esperando   trigger
#                → Trigger detectado         5177 ms
# ---------------------------------------------------------
#  128/100000	        Esperando   trigger
#                → Trigger detectado         5215 ms
# ---------------------------------------------------------
#  129/100000	        Esperando   trigger
#                → Trigger detectado         5257 ms
# ---------------------------------------------------------
#  130/100000	        Esperando   trigger
#                → Trigger detectado         5296 ms
# ---------------------------------------------------------
#  131/100000	        Esperando   trigger
#                → Trigger detectado         5336 ms
# ---------------------------------------------------------
#  132/100000	        Esperando   trigger
#                → Trigger detectado         5391 ms
# ---------------------------------------------------------
#  133/100000	        Esperando   trigger
#                → Trigger detectado         5432 ms
# ---------------------------------------------------------
#  134/100000	        Esperando   trigger
#                → Trigger detectado         5469 ms
# ---------------------------------------------------------
#  135/100000	        Esperando   trigger
#                → Trigger detectado         5508 ms
# ---------------------------------------------------------
#  136/100000	        Esperando   trigger
#                → Trigger detectado         5566 ms
# ---------------------------------------------------------
#  137/100000	        Esperando   trigger
#                → Trigger detectado         5604 ms
# ---------------------------------------------------------
#  138/100000	        Esperando   trigger
#                → Trigger detectado         5640 ms
# ---------------------------------------------------------
#  139/100000	        Esperando   trigger
#                → Trigger detectado         5680 ms
# ---------------------------------------------------------
#  140/100000	        Esperando   trigger
#                → Trigger detectado         5719 ms
# ---------------------------------------------------------
#  141/100000	        Esperando   trigger
#                → Trigger detectado         5771 ms
# ---------------------------------------------------------
#  142/100000	        Esperando   trigger
#                → Trigger detectado         5810 ms
# ---------------------------------------------------------
#  143/100000	        Esperando   trigger
#                → Trigger detectado         5853 ms
# ---------------------------------------------------------
#  144/100000	        Esperando   trigger
#                → Trigger detectado         5889 ms
# ---------------------------------------------------------
#  145/100000	        Esperando   trigger
#                → Trigger detectado         5930 ms
# ---------------------------------------------------------
#  146/100000	        Esperando   trigger
#                → Trigger detectado         5978 ms
# ---------------------------------------------------------
#  147/100000	        Esperando   trigger
#                → Trigger detectado         6015 ms
# ---------------------------------------------------------
#  148/100000	        Esperando   trigger
#                → Trigger detectado         6056 ms
# ---------------------------------------------------------
#  149/100000	        Esperando   trigger
#                → Trigger detectado         6094 ms
# ---------------------------------------------------------
#  150/100000	        Esperando   trigger
#                → Trigger detectado         6144 ms
# ---------------------------------------------------------
#  151/100000	        Esperando   trigger
#                → Trigger detectado         6192 ms
# ---------------------------------------------------------
#  152/100000	        Esperando   trigger
#                → Trigger detectado         6229 ms
# ---------------------------------------------------------
#  153/100000	        Esperando   trigger
#                → Trigger detectado         6274 ms
# ---------------------------------------------------------
#  154/100000	        Esperando   trigger
#                → Trigger detectado         6313 ms
# ---------------------------------------------------------
#  155/100000	        Esperando   trigger
#                → Trigger detectado         6354 ms
# ---------------------------------------------------------
#  156/100000	        Esperando   trigger
#                → Trigger detectado         6410 ms
# ---------------------------------------------------------
#  157/100000	        Esperando   trigger
#                → Trigger detectado         6452 ms
# ---------------------------------------------------------
#  158/100000	        Esperando   trigger
#                → Trigger detectado         6490 ms
# ---------------------------------------------------------
#  159/100000	        Esperando   trigger
#                → Trigger detectado         6529 ms
# ---------------------------------------------------------
#  160/100000	        Esperando   trigger
#                → Trigger detectado         6565 ms
# ---------------------------------------------------------
#  161/100000	        Esperando   trigger
#                → Trigger detectado         6618 ms
# ---------------------------------------------------------
#  162/100000	        Esperando   trigger
#                → Trigger detectado         6657 ms
# ---------------------------------------------------------
#  163/100000	        Esperando   trigger
#                → Trigger detectado         6695 ms
# ---------------------------------------------------------
#  164/100000	        Esperando   trigger
#                → Trigger detectado         6734 ms
# ---------------------------------------------------------
#  165/100000	        Esperando   trigger
#                → Trigger detectado         6773 ms
# ---------------------------------------------------------
#  166/100000	        Esperando   trigger
#                → Trigger detectado         6814 ms
# ---------------------------------------------------------
#  167/100000	        Esperando   trigger
#                → Trigger detectado         6853 ms
# ---------------------------------------------------------
#  168/100000	        Esperando   trigger
#                → Trigger detectado         6890 ms
# ---------------------------------------------------------
#  169/100000	        Esperando   trigger
#                → Trigger detectado         6930 ms
# ---------------------------------------------------------
#  170/100000	        Esperando   trigger
#                → Trigger detectado         6971 ms
# ---------------------------------------------------------
#  171/100000	        Esperando   trigger
#                → Trigger detectado         7008 ms
# ---------------------------------------------------------
#  172/100000	        Esperando   trigger
#                → Trigger detectado         7053 ms
# ---------------------------------------------------------
#  173/100000	        Esperando   trigger
#                → Trigger detectado         7089 ms
# ---------------------------------------------------------
#  174/100000	        Esperando   trigger
#                → Trigger detectado         7124 ms
# ---------------------------------------------------------
#  175/100000	        Esperando   trigger
#                → Trigger detectado         7164 ms
# ---------------------------------------------------------
#  176/100000	        Esperando   trigger
#                → Trigger detectado         7203 ms
# ---------------------------------------------------------
#  177/100000	        Esperando   trigger
#                → Trigger detectado         7245 ms
# ---------------------------------------------------------
#  178/100000	        Esperando   trigger
#                → Trigger detectado         7295 ms
# ---------------------------------------------------------
#  179/100000	        Esperando   trigger
#                → Trigger detectado         7332 ms
# ---------------------------------------------------------
#  180/100000	        Esperando   trigger
#                → Trigger detectado         7368 ms
# ---------------------------------------------------------
#  181/100000	        Esperando   trigger
#                → Trigger detectado         7406 ms
# ---------------------------------------------------------
#  182/100000	        Esperando   trigger
#                → Trigger detectado         7448 ms
# ---------------------------------------------------------
#  183/100000	        Esperando   trigger
#                → Trigger detectado         7491 ms
# ---------------------------------------------------------
#  184/100000	        Esperando   trigger
#                → Trigger detectado         7531 ms
# ---------------------------------------------------------
#  185/100000	        Esperando   trigger
#                → Trigger detectado         7568 ms
# ---------------------------------------------------------
#  186/100000	        Esperando   trigger
#                → Trigger detectado         7604 ms
# ---------------------------------------------------------
#  187/100000	        Esperando   trigger
#                → Trigger detectado         7641 ms
# ---------------------------------------------------------
#  188/100000	        Esperando   trigger
#                → Trigger detectado         7678 ms
# ---------------------------------------------------------
#  189/100000	        Esperando   trigger
#                → Trigger detectado         7727 ms
# ---------------------------------------------------------
#  190/100000	        Esperando   trigger
#                → Trigger detectado         7765 ms
# ---------------------------------------------------------
#  191/100000	        Esperando   trigger
#                → Trigger detectado         7814 ms
# ---------------------------------------------------------
#  192/100000	        Esperando   trigger
#                → Trigger detectado         7850 ms
# ---------------------------------------------------------
#  193/100000	        Esperando   trigger
#                → Trigger detectado         7889 ms
# ---------------------------------------------------------
#  194/100000	        Esperando   trigger
#                → Trigger detectado         7933 ms
# ---------------------------------------------------------
#  195/100000	        Esperando   trigger
#                → Trigger detectado         7973 ms
# ---------------------------------------------------------
#  196/100000	        Esperando   trigger
#                → Trigger detectado         8011 ms
# ---------------------------------------------------------
#  197/100000	        Esperando   trigger
#                → Trigger detectado         8056 ms
# ---------------------------------------------------------
#  198/100000	        Esperando   trigger
#                → Trigger detectado         8092 ms
# ---------------------------------------------------------
#  199/100000	        Esperando   trigger
#                → Trigger detectado         8137 ms
# ---------------------------------------------------------
#  200/100000	        Esperando   trigger
#                → Trigger detectado         8178 ms
# ---------------------------------------------------------
#  201/100000	        Esperando   trigger
#                → Trigger detectado         8216 ms
# ---------------------------------------------------------
#  202/100000	        Esperando   trigger
#                → Trigger detectado         8252 ms
# ---------------------------------------------------------
#  203/100000	        Esperando   trigger
#                → Trigger detectado         8288 ms
# ---------------------------------------------------------
#  204/100000	        Esperando   trigger
#                → Trigger detectado         8329 ms
# ---------------------------------------------------------
#  205/100000	        Esperando   trigger
#                → Trigger detectado         8378 ms
# ---------------------------------------------------------
#  206/100000	        Esperando   trigger
#                → Trigger detectado         8426 ms
# ---------------------------------------------------------
#  207/100000	        Esperando   trigger
#                → Trigger detectado         8462 ms
# ---------------------------------------------------------
#  208/100000	        Esperando   trigger
#                → Trigger detectado         8498 ms
# ---------------------------------------------------------
#  209/100000	        Esperando   trigger
#                → Trigger detectado         8534 ms
# ---------------------------------------------------------
#  210/100000	        Esperando   trigger
#                → Trigger detectado         8573 ms
# ---------------------------------------------------------
#  211/100000	        Esperando   trigger
#                → Trigger detectado         8620 ms
# ---------------------------------------------------------
#  212/100000	        Esperando   trigger
#                → Trigger detectado         8658 ms
# ---------------------------------------------------------
#  213/100000	        Esperando   trigger
#                → Trigger detectado         8694 ms
# ---------------------------------------------------------
#  214/100000	        Esperando   trigger
#                → Trigger detectado         8733 ms
# ---------------------------------------------------------
#  215/100000	        Esperando   trigger
#                → Trigger detectado         8769 ms
# ---------------------------------------------------------
#  216/100000	        Esperando   trigger
#                → Trigger detectado         8812 ms
# ---------------------------------------------------------
#  217/100000	        Esperando   trigger
#                → Trigger detectado         8852 ms
# ---------------------------------------------------------
#  218/100000	        Esperando   trigger
#                → Trigger detectado         8897 ms
# ---------------------------------------------------------
#  219/100000	        Esperando   trigger
#                → Trigger detectado         8934 ms
# ---------------------------------------------------------
#  220/100000	        Esperando   trigger
#                → Trigger detectado         8983 ms
# ---------------------------------------------------------
#  221/100000	        Esperando   trigger
#                → Trigger detectado         9025 ms
# ---------------------------------------------------------
#  222/100000	        Esperando   trigger
#                → Trigger detectado         9063 ms
# ---------------------------------------------------------
#  223/100000	        Esperando   trigger
#                → Trigger detectado         9099 ms
# ---------------------------------------------------------
#  224/100000	        Esperando   trigger
#                → Trigger detectado         9137 ms
# ---------------------------------------------------------
#  225/100000	        Esperando   trigger
#                → Trigger detectado         9174 ms
# ---------------------------------------------------------
#  226/100000	        Esperando   trigger
#                → Trigger detectado         9217 ms
# ---------------------------------------------------------
#  227/100000	        Esperando   trigger
#                → Trigger detectado         9263 ms
# ---------------------------------------------------------
#  228/100000	        Esperando   trigger
#                → Trigger detectado         9301 ms
# ---------------------------------------------------------
#  229/100000	        Esperando   trigger
#                → Trigger detectado         9337 ms
# ---------------------------------------------------------
#  230/100000	        Esperando   trigger
#                → Trigger detectado         9372 ms
# ---------------------------------------------------------
#  231/100000	        Esperando   trigger
#                → Trigger detectado         9410 ms
# ---------------------------------------------------------
#  232/100000	        Esperando   trigger
#                → Trigger detectado         9447 ms
# ---------------------------------------------------------
#  233/100000	        Esperando   trigger
#                → Trigger detectado         9494 ms
# ---------------------------------------------------------
#  234/100000	        Esperando   trigger
#                → Trigger detectado         9532 ms
# ---------------------------------------------------------
#  235/100000	        Esperando   trigger
#                → Trigger detectado         9581 ms
# ---------------------------------------------------------
#  236/100000	        Esperando   trigger
#                → Trigger detectado         9618 ms
# ---------------------------------------------------------
#  237/100000	        Esperando   trigger
#                → Trigger detectado         9661 ms
# ---------------------------------------------------------
#  238/100000	        Esperando   trigger
#                → Trigger detectado         9703 ms
# ---------------------------------------------------------
#  239/100000	        Esperando   trigger
#                → Trigger detectado         9741 ms
# ---------------------------------------------------------
#  240/100000	        Esperando   trigger
#                → Trigger detectado         9783 ms
# ---------------------------------------------------------
#  241/100000	        Esperando   trigger
#                → Trigger detectado         9820 ms
# ---------------------------------------------------------
#  242/100000	        Esperando   trigger
#                → Trigger detectado         9861 ms
# ---------------------------------------------------------
#  243/100000	        Esperando   trigger
#                → Trigger detectado         9897 ms
# ---------------------------------------------------------
#  244/100000	        Esperando   trigger
#                → Trigger detectado         9941 ms
# ---------------------------------------------------------
#  245/100000	        Esperando   trigger
#                → Trigger detectado         9985 ms
# ---------------------------------------------------------
#  246/100000	        Esperando   trigger
#                → Trigger detectado         10028 ms
# ---------------------------------------------------------
#  247/100000	        Esperando   trigger
#                → Trigger detectado         10068 ms
# ---------------------------------------------------------
#  248/100000	        Esperando   trigger
#                → Trigger detectado         10105 ms
# ---------------------------------------------------------
#  249/100000	        Esperando   trigger
#                → Trigger detectado         10148 ms
# ---------------------------------------------------------
#  250/100000	        Esperando   trigger
#                → Trigger detectado         10189 ms
# ---------------------------------------------------------
#  251/100000	        Esperando   trigger
#                → Trigger detectado         10225 ms
# ---------------------------------------------------------
#  252/100000	        Esperando   trigger
#                → Trigger detectado         10264 ms
# ---------------------------------------------------------
#  253/100000	        Esperando   trigger
#                → Trigger detectado         10302 ms
# ---------------------------------------------------------
#  254/100000	        Esperando   trigger
#                → Trigger detectado         10338 ms
# ---------------------------------------------------------
#  255/100000	        Esperando   trigger
#                → Trigger detectado         10382 ms
# ---------------------------------------------------------
#  256/100000	        Esperando   trigger
#                → Trigger detectado         10424 ms
# ---------------------------------------------------------
#  257/100000	        Esperando   trigger
#                → Trigger detectado         10470 ms
# ---------------------------------------------------------
#  258/100000	        Esperando   trigger
#                → Trigger detectado         10508 ms
# ---------------------------------------------------------
#  259/100000	        Esperando   trigger
#                → Trigger detectado         10545 ms
# ---------------------------------------------------------
#  260/100000	        Esperando   trigger
#                → Trigger detectado         10581 ms
# ---------------------------------------------------------
#  261/100000	        Esperando   trigger
#                → Trigger detectado         10625 ms
# ---------------------------------------------------------
#  262/100000	        Esperando   trigger
#                → Trigger detectado         10662 ms
# ---------------------------------------------------------
#  263/100000	        Esperando   trigger
#                → Trigger detectado         10698 ms
# ---------------------------------------------------------
#  264/100000	        Esperando   trigger
#                → Trigger detectado         10740 ms
# ---------------------------------------------------------
#  265/100000	        Esperando   trigger
#                → Trigger detectado         10783 ms
# ---------------------------------------------------------
#  266/100000	        Esperando   trigger
#                → Trigger detectado         10819 ms
# ---------------------------------------------------------
#  267/100000	        Esperando   trigger
#                → Trigger detectado         10867 ms
# ---------------------------------------------------------
#  268/100000	        Esperando   trigger
#                → Trigger detectado         10903 ms
# ---------------------------------------------------------
#  269/100000	        Esperando   trigger
#                → Trigger detectado         10941 ms
# ---------------------------------------------------------
#  270/100000	        Esperando   trigger
#                → Trigger detectado         10994 ms
# ---------------------------------------------------------
#  271/100000	        Esperando   trigger
#                → Trigger detectado         11033 ms
# ---------------------------------------------------------
#  272/100000	        Esperando   trigger
#                → Trigger detectado         11075 ms
# ---------------------------------------------------------
#  273/100000	        Esperando   trigger
#                → Trigger detectado         11135 ms
# ---------------------------------------------------------
#  274/100000	        Esperando   trigger
#                → Trigger detectado         11174 ms
# ---------------------------------------------------------
#  275/100000	        Esperando   trigger
#                → Trigger detectado         11210 ms
# ---------------------------------------------------------
#  276/100000	        Esperando   trigger
#                → Trigger detectado         11248 ms
# ---------------------------------------------------------
#  277/100000	        Esperando   trigger
#                → Trigger detectado         11297 ms
# ---------------------------------------------------------
#  278/100000	        Esperando   trigger
#                → Trigger detectado         11336 ms
# ---------------------------------------------------------
#  279/100000	        Esperando   trigger
#                → Trigger detectado         11372 ms
# ---------------------------------------------------------
#  280/100000	        Esperando   trigger
#                → Trigger detectado         11409 ms
# ---------------------------------------------------------
#  281/100000	        Esperando   trigger
#                → Trigger detectado         11444 ms
# ---------------------------------------------------------
#  282/100000	        Esperando   trigger
#                → Trigger detectado         11480 ms
# ---------------------------------------------------------
#  283/100000	        Esperando   trigger
#                → Trigger detectado         11527 ms
# ---------------------------------------------------------
#  284/100000	        Esperando   trigger
#                → Trigger detectado         11564 ms
# ---------------------------------------------------------
#  285/100000	        Esperando   trigger
#                → Trigger detectado         11604 ms
# ---------------------------------------------------------
#  286/100000	        Esperando   trigger
#                → Trigger detectado         11640 ms
# ---------------------------------------------------------
#  287/100000	        Esperando   trigger
#                → Trigger detectado         11677 ms
# ---------------------------------------------------------
#  288/100000	        Esperando   trigger
#                → Trigger detectado         11730 ms
# ---------------------------------------------------------
#  289/100000	        Esperando   trigger
#                → Trigger detectado         11768 ms
# ---------------------------------------------------------
#  290/100000	        Esperando   trigger
#                → Trigger detectado         11807 ms
# ---------------------------------------------------------
#  291/100000	        Esperando   trigger
#                → Trigger detectado         11845 ms
# ---------------------------------------------------------
#  292/100000	        Esperando   trigger
#                → Trigger detectado         11884 ms
# ---------------------------------------------------------
#  293/100000	        Esperando   trigger
#                → Trigger detectado         11927 ms
# ---------------------------------------------------------
#  294/100000	        Esperando   trigger
#                → Trigger detectado         11973 ms
# ---------------------------------------------------------
#  295/100000	        Esperando   trigger
#                → Trigger detectado         12018 ms
# ---------------------------------------------------------
#  296/100000	        Esperando   trigger
#                → Trigger detectado         12056 ms
# ---------------------------------------------------------
#  297/100000	        Esperando   trigger
#                → Trigger detectado         12094 ms
# ---------------------------------------------------------
#  298/100000	        Esperando   trigger
#                → Trigger detectado         12130 ms
# ...
#                → Trigger detectado         141619 ms
# ---------------------------------------------------------
#  3236/100000	        Esperando   trigger
#                → Trigger detectado         141659 ms
# ---------------------------------------------------------
#  3237/100000	        Esperando   trigger
#                → Trigger detectado         141701 ms
# ---------------------------------------------------------
#  3238/100000	        Esperando   trigger
#                → Trigger detectado         141750 ms
# ---------------------------------------------------------
#  3239/100000	        Esperando   trigger
#                → Trigger detectado         141789 ms
# ---------------------------------------------------------
#  3240/100000	        Esperando   trigger
#                → Trigger detectado         141843 ms
# ---------------------------------------------------------
#  3241/100000	        Esperando   trigger
#                → Trigger detectado         141883 ms
# ---------------------------------------------------------
#  3242/100000	        Esperando   trigger
#                → Trigger detectado         141923 ms
# ---------------------------------------------------------
#  3243/100000	        Esperando   trigger
#                → Trigger detectado         141966 ms
# ---------------------------------------------------------
#  3244/100000	        Esperando   trigger
#                → Trigger detectado         142004 ms
# ---------------------------------------------------------
#  3245/100000	        Esperando   trigger
#                → Trigger detectado         142044 ms
# ---------------------------------------------------------
#  3246/100000	        Esperando   trigger
#                → Trigger detectado         142101 ms
# ---------------------------------------------------------
#  3247/100000	        Esperando   trigger
#                → Trigger detectado         142143 ms
# ---------------------------------------------------------
#  3248/100000	        Esperando   trigger
#                → Trigger detectado         142182 ms
# ---------------------------------------------------------
#  3249/100000	        Esperando   trigger
#                → Trigger detectado         142223 ms
# ---------------------------------------------------------
#  3250/100000	        Esperando   trigger
#                → Trigger detectado         142261 ms
# ---------------------------------------------------------
#  3251/100000	        Esperando   trigger
#                → Trigger detectado         142312 ms
# ---------------------------------------------------------
#  3252/100000	        Esperando   trigger
#                → Trigger detectado         142354 ms
# ---------------------------------------------------------
#  3253/100000	        Esperando   trigger
#                → Trigger detectado         142394 ms
# ---------------------------------------------------------
#  3254/100000	        Esperando   trigger
#                → Trigger detectado         142446 ms
# ---------------------------------------------------------
#  3255/100000	        Esperando   trigger
#                → Trigger detectado         142494 ms
# ---------------------------------------------------------
#  3256/100000	        Esperando   trigger
#                → Trigger detectado         142547 ms
# ---------------------------------------------------------
#  3257/100000	        Esperando   trigger
#                → Trigger detectado         142587 ms
# ---------------------------------------------------------
#  3258/100000	        Esperando   trigger
#                → Trigger detectado         142630 ms
# ---------------------------------------------------------
#  3259/100000	        Esperando   trigger
#                → Trigger detectado         142669 ms
# ---------------------------------------------------------
#  3260/100000	        Esperando   trigger
#                → Trigger detectado         142715 ms
# ---------------------------------------------------------
#  3261/100000	        Esperando   trigger
#                → Trigger detectado         142765 ms
# ---------------------------------------------------------
#  3262/100000	        Esperando   trigger
#                → Trigger detectado         142812 ms
# ---------------------------------------------------------
#  3263/100000	        Esperando   trigger
#                → Trigger detectado         142851 ms
# ---------------------------------------------------------
#  3264/100000	        Esperando   trigger
#                → Trigger detectado         142888 ms
# ---------------------------------------------------------
#  3265/100000	        Esperando   trigger
#                → Trigger detectado         142930 ms
# ---------------------------------------------------------
#  3266/100000	        Esperando   trigger
#                → Trigger detectado         142975 ms
# ---------------------------------------------------------
#  3267/100000	        Esperando   trigger
#                → Trigger detectado         143017 ms
# ---------------------------------------------------------
#  3268/100000	        Esperando   trigger
#                → Trigger detectado         143058 ms
# ---------------------------------------------------------
#  3269/100000	        Esperando   trigger
#                → Trigger detectado         143096 ms
# ---------------------------------------------------------
#  3270/100000	        Esperando   trigger
#                → Trigger detectado         143139 ms
# ---------------------------------------------------------
#  3271/100000	        Esperando   trigger
#                → Trigger detectado         143187 ms
# ---------------------------------------------------------
#  3272/100000	        Esperando   trigger
#                → Trigger detectado         143230 ms
# ---------------------------------------------------------
#  3273/100000	        Esperando   trigger
#                → Trigger detectado         143276 ms
# ---------------------------------------------------------
#  3274/100000	        Esperando   trigger
#                → Trigger detectado         143319 ms
# ---------------------------------------------------------
#  3275/100000	        Esperando   trigger
#                → Trigger detectado         143362 ms
# ---------------------------------------------------------
#  3276/100000	        Esperando   trigger
#                → Trigger detectado         143410 ms
# ---------------------------------------------------------
#  3277/100000	        Esperando   trigger
#                → Trigger detectado         143456 ms
# ---------------------------------------------------------
#  3278/100000	        Esperando   trigger
#                → Trigger detectado         143499 ms
# ---------------------------------------------------------
#  3279/100000	        Esperando   trigger
#                → Trigger detectado         143541 ms
# ---------------------------------------------------------
#  3280/100000	        Esperando   trigger
#                → Trigger detectado         143583 ms
# ---------------------------------------------------------
#  3281/100000	        Esperando   trigger
#                → Trigger detectado         143635 ms
# ---------------------------------------------------------
#  3282/100000	        Esperando   trigger
#                → Trigger detectado         143682 ms
# ---------------------------------------------------------
#  3283/100000	        Esperando   trigger
#                → Trigger detectado         143726 ms
# ---------------------------------------------------------
#  3284/100000	        Esperando   trigger
#                → Trigger detectado         143771 ms
# ---------------------------------------------------------
#  3285/100000	        Esperando   trigger
#                → Trigger detectado         143812 ms
# ---------------------------------------------------------
#  3286/100000	        Esperando   trigger
#                → Trigger detectado         143862 ms
# ---------------------------------------------------------
#  3287/100000	        Esperando   trigger
#                → Trigger detectado         143908 ms
# ---------------------------------------------------------
#  3288/100000	        Esperando   trigger
#                → Trigger detectado         143960 ms
# ---------------------------------------------------------
#  3289/100000	        Esperando   trigger
#                → Trigger detectado         144014 ms
# ---------------------------------------------------------
#  3290/100000	        Esperando   trigger
#                → Trigger detectado         144054 ms
# ---------------------------------------------------------
#  3291/100000	        Esperando   trigger
#                → Trigger detectado         144126 ms
# ---------------------------------------------------------
#  3292/100000	        Esperando   trigger
#                → Trigger detectado         144169 ms
# ---------------------------------------------------------
#  3293/100000	        Esperando   trigger
#                → Trigger detectado         144208 ms
# ---------------------------------------------------------
#  3294/100000	        Esperando   trigger
#                → Trigger detectado         144252 ms
# ---------------------------------------------------------
#  3295/100000	        Esperando   trigger
#                → Trigger detectado         144293 ms
# ---------------------------------------------------------
#  3296/100000	        Esperando   trigger
#                → Trigger detectado         144350 ms
# ---------------------------------------------------------
#  3297/100000	        Esperando   trigger
#                → Trigger detectado         144400 ms
# ---------------------------------------------------------
#  3298/100000	        Esperando   trigger
#                → Trigger detectado         144441 ms
# ---------------------------------------------------------
#  3299/100000	        Esperando   trigger
#                → Trigger detectado         144488 ms
# ---------------------------------------------------------
#  3300/100000	        Esperando   trigger
#                → Trigger detectado         144538 ms
# ---------------------------------------------------------
#  3301/100000	        Esperando   trigger
#                → Trigger detectado         144591 ms
# ---------------------------------------------------------
#  3302/100000	        Esperando   trigger
#                → Trigger detectado         144629 ms
# ---------------------------------------------------------
#  3303/100000	        Esperando   trigger
#                → Trigger detectado         144667 ms
# ---------------------------------------------------------
#  3304/100000	        Esperando   trigger
#                → Trigger detectado         144705 ms
# ---------------------------------------------------------
#  3305/100000	        Esperando   trigger
#                → Trigger detectado         144750 ms
# ---------------------------------------------------------
#  3306/100000	        Esperando   trigger
#                → Trigger detectado         144788 ms
# ---------------------------------------------------------
#  3307/100000	        Esperando   trigger
#                → Trigger detectado         144840 ms
# ---------------------------------------------------------
#  3308/100000	        Esperando   trigger
#                → Trigger detectado         144880 ms
# ---------------------------------------------------------
#  3309/100000	        Esperando   trigger
#                → Trigger detectado         144918 ms
# ---------------------------------------------------------
#  3310/100000	        Esperando   trigger
#                → Trigger detectado         144961 ms
# ---------------------------------------------------------
#  3311/100000	        Esperando   trigger
#                → Trigger detectado         145008 ms
# ---------------------------------------------------------
#  3312/100000	        Esperando   trigger
#                → Trigger detectado         145058 ms
# ---------------------------------------------------------
#  3313/100000	        Esperando   trigger
#                → Trigger detectado         145104 ms
# ---------------------------------------------------------
#  3314/100000	        Esperando   trigger
#                → Trigger detectado         145144 ms
# ---------------------------------------------------------
#  3315/100000	        Esperando   trigger
#                → Trigger detectado         145188 ms
# ---------------------------------------------------------
#  3316/100000	        Esperando   trigger
#                → Trigger detectado         145229 ms
# ---------------------------------------------------------
#  3317/100000	        Esperando   trigger
#                → Trigger detectado         145278 ms
# ---------------------------------------------------------
#  3318/100000	        Esperando   trigger
#                → Trigger detectado         145323 ms
# ---------------------------------------------------------
#  3319/100000	        Esperando   trigger
#                → Trigger detectado         145367 ms
# ---------------------------------------------------------
#  3320/100000	        Esperando   trigger
#                → Trigger detectado         145407 ms
# ---------------------------------------------------------
#  3321/100000	        Esperando   trigger
#                → Trigger detectado         145448 ms
# ---------------------------------------------------------
#  3322/100000	        Esperando   trigger
#                → Trigger detectado         145507 ms
# ---------------------------------------------------------
#  3323/100000	        Esperando   trigger
#                → Trigger detectado         145556 ms
# ---------------------------------------------------------
#  3324/100000	        Esperando   trigger
#                → Trigger detectado         145600 ms
# ---------------------------------------------------------
#  3325/100000	        Esperando   trigger
#                → Trigger detectado         145644 ms
# ---------------------------------------------------------
#  3326/100000	        Esperando   trigger
#                → Trigger detectado         145689 ms
# ---------------------------------------------------------
#  3327/100000	        Esperando   trigger
#                → Trigger detectado         145739 ms
# ---------------------------------------------------------
#  3328/100000	        Esperando   trigger
#                → Trigger detectado         145776 ms
# ---------------------------------------------------------
#  3329/100000	        Esperando   trigger
#                → Trigger detectado         145834 ms
# ---------------------------------------------------------
#  3330/100000	        Esperando   trigger
#                → Trigger detectado         145876 ms
# ---------------------------------------------------------
#  3331/100000	        Esperando   trigger
#                → Trigger detectado         145923 ms
# ---------------------------------------------------------
#  3332/100000	        Esperando   trigger
#                → Trigger detectado         145975 ms
# ---------------------------------------------------------
#  3333/100000	        Esperando   trigger
#                → Trigger detectado         146013 ms
# ---------------------------------------------------------
#  3334/100000	        Esperando   trigger
#                → Trigger detectado         146054 ms
# ---------------------------------------------------------
#  3335/100000	        Esperando   trigger
#                → Trigger detectado         146099 ms
# ---------------------------------------------------------
#  3336/100000	        Esperando   trigger
#                → Trigger detectado         146140 ms
# ---------------------------------------------------------
